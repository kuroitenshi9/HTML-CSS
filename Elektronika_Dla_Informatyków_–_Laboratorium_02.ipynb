# %% [markdown]
# <a href="https://colab.research.google.com/github/kuroitenshi9/HTML-CSS/blob/master/Elektronika_Dla_Informatyk%C3%B3w_%E2%80%93_Laboratorium_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ewa Bielawska 58442
#
# Obliczenia i wykresy
#
# ##1. Dioda Prostownicza

# %%
import pandas as pd
import matplotlib.pyplot as plt

'''
wzór na rezystencje dynamiczna ℝ𝒅𝒚𝒏 = (𝑼𝒌− 𝑼𝒌−𝟏) / (𝑰𝒌− 𝑰𝒌−𝟏)
'''

U = list(range(0, 13))
I = [0, 0.58, 1.529, 2.504, 3.487, 4.474, 5.464, 6.455, 7.448, 8.441, 9.435, 10.43, 11.425]

Rdyn = [0]

for k in range(1, len(U)):
    delta_U = U[k] - U[k - 1]
    delta_I = I[k] - I[k - 1]
    R = delta_U / (delta_I / 1000)
    Rdyn.append(round(R,3))


wyniki = pd.DataFrame({
    "U [V]": U,
    "I [mA]": I,
    "Rdyn [Ω]": Rdyn
})

fig, ax = plt.subplots(figsize=(12, 2.5))
ax.axis('off')
table_data = [
    ["U [V]"] + U,
    ["I [mA]"] + [f"{x:.3f}" for x in I],
    ["Rdyn [Ω]"] + ["N/A" if x is None else str(x) for x in Rdyn]
]
table = ax.table(cellText=table_data, loc='center', cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)
plt.title("Tabela nr 1A: Pomiary diody prostowniczej w kierunku przewodzenia")


plt.figure(figsize=(8, 5))
plt.plot(U[0:], Rdyn[0:], marker='o', color='blue')
plt.title("Rezystancja dynamiczna dla diody prostowniczej w kierunku przewodzenia")
plt.xlabel("U [V]")
plt.ylabel("Rdyn [Ω]")
plt.grid(True)
plt.tight_layout()
plt.xlim(0, max(U) if U else 1)
plt.ylim(0, max(Rdyn) if Rdyn else 1)
# Out:
# (0.0, 1724.138)

# %%
U = list(range(0, 13))
I = [-171.435] * 13 #w nA
I[0] = 0

Rdyn = [0]

for k in range(1, len(U)):
    delta_U = U[k] - U[k - 1]
    delta_I = I[k] - I[k - 1]
    if delta_I == 0:
        R = float('inf')
    else:
        R = delta_U / (delta_I / 10**9)
    Rdyn.append(round(R,3))

wyniki = pd.DataFrame({
    "U [V]": U,
    "I [nA]": I,
    "Rdyn [Ω]": Rdyn
})

fig, ax = plt.subplots(figsize=(12, 2.5))
ax.axis('off')
table_data = [
    ["U [V]"] + U,
    ["I [nA]"] + [f"{x:.3f}" for x in I],
    ["Rdyn [Ω]"] + ["N/A" if x is None else str(x) for x in Rdyn]
]
table = ax.table(cellText=table_data, loc='center', cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)
plt.title("Tabela nr 1B: Pomiary diody prostowniczej w kierunku zaporowym")



plt.figure(figsize=(8, 5))
plt.plot(U[0:], Rdyn[0:], marker='o', color='blue')
plt.title("Rezystancja dynamiczna dla diody prostowniczej w kierunku zaporowym")
plt.xlabel("U [V]")
plt.ylabel("Rdyn [Ω]")
plt.grid(True)
plt.tight_layout()
plt.xlim(0, max(U) if U else 1)
plt.ylim(0, max(Rdyn) if Rdyn else 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-576686ce9f10> in <cell line: 0>()
#      43 plt.tight_layout()
#      44 plt.xlim(0, max(U) if U else 1)
# ---> 45 plt.ylim(0, max(Rdyn) if Rdyn else 1)
#      46
#      47
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in ylim(*args, **kwargs)
#    2158     if not args and not kwargs:
#    2159         return ax.get_ylim()
# -> 2160     ret = ax.set_ylim(*args, **kwargs)
#    2161     return ret
#    2162
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    4015                 raise TypeError("Cannot pass both 'top' and 'ymax'")
#    4016             top = ymax
# -> 4017         return self.yaxis._set_lim(bottom, top, emit=emit, auto=auto)
#    4018
# ...

# %% [markdown]
# ##2. Dioda Zenera

# %%
U = list(range(0, 13))
I = [0, 0.58, 1.529, 2.504, 3.487, 4.474, 5.464, 6.455, 7.448, 8.441, 9.435, 10.43, 11.425] #w mA

Rdyn = [0]

for k in range(1, len(U)):
    delta_U = U[k] - U[k - 1]
    delta_I = I[k] - I[k - 1]
    if delta_I == 0:
        R = float('inf')
    else:
        R = delta_U / (delta_I / 1000)
    Rdyn.append(round(R,3))

wyniki = pd.DataFrame({
    "U [V]": U,
    "I [mA]": I,
    "Rdyn [Ω]": Rdyn
})

fig, ax = plt.subplots(figsize=(12, 2.5))
ax.axis('off')
table_data = [
    ["U [V]"] + U,
    ["I [mA]"] + [f"{x:.3f}" for x in I],
    ["Rdyn [Ω]"] + ["N/A" if x is None else str(x) for x in Rdyn]
]
table = ax.table(cellText=table_data, loc='center', cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)
plt.title("Tabela nr 2A: Pomiary diody Zenera w kierunku przewodzenia")



plt.figure(figsize=(8, 5))
plt.plot(U[0:], Rdyn[0:], marker='o', color='red')
plt.title("Rezystancja dynamiczna dla diody Zenera w kierunku przewodzenia")
plt.xlabel("U [V]")
plt.ylabel("Rdyn [Ω]")
plt.grid(True)
plt.tight_layout()
plt.xlim(0, max(U) if U else 1)
plt.ylim(0, max(Rdyn) if Rdyn else 1)
# Out:
# (0.0, 1724.138)

# %%
U = list(range(0, 13))
I = [0, -0.000171435, -0.000171435, -0.000171435, -0.000171435, -0.000171436,
     -0.462, -1.432, -2.419, -3.41, -4.403, -5.398, -6.394] #w mA

Rdyn = [0]

for k in range(1, len(U)):
    delta_U = U[k] - U[k - 1]
    delta_I = I[k] - I[k - 1]
    delta_I = I[k] - I[k - 1]
    if delta_I == 0:
        R = float('inf')
    else:
        R = delta_U / (delta_I / 1000)
    Rdyn.append(round(R,10))

wyniki = pd.DataFrame({
    "U [V]": U,
    "I [mA]": I,
    "Rdyn [Ω]": Rdyn
})

fig, ax = plt.subplots(figsize=(25, 2.5))
ax.axis('off')
table_data = [
    ["U [V]"] + U,
    ["I [mA]"] + [f"{x:.5f}" for x in I],
    ["Rdyn [Ω]"] + ["N/A" if x is None else f"{x:.3f}" for x in Rdyn]
]
table = ax.table(cellText=table_data, loc='center', cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)
plt.title("Tabela nr 2B: Pomiary diody Zenera w kierunku zaporowym")



plt.figure(figsize=(8, 5))
plt.plot(U[0:], Rdyn[0:], marker='o', color='red')
plt.title("Rezystancja dynamiczna dla diody Zenera w kierunku zaporowym")
plt.xlabel("U [V]")
plt.ylabel("Rdyn [Ω]")
plt.grid(True)
plt.tight_layout()
plt.xlim(0, max(U) if U else 1)

plt.ylim(0, max(Rdyn) if Rdyn else 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-e7c3555596f5> in <cell line: 0>()
#      45 plt.xlim(0, max(U) if U else 1)
#      46
# ---> 47 plt.ylim(0, max(Rdyn) if Rdyn else 1)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in ylim(*args, **kwargs)
#    2158     if not args and not kwargs:
#    2159         return ax.get_ylim()
# -> 2160     ret = ax.set_ylim(*args, **kwargs)
#    2161     return ret
#    2162
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    4015                 raise TypeError("Cannot pass both 'top' and 'ymax'")
#    4016             top = ymax
# -> 4017         return self.yaxis._set_lim(bottom, top, emit=emit, auto=auto)
#    4018
#    4019     get_yscale = _axis_method_wrapper("yaxis", "get_scale")
#
# ...

# %% [markdown]
# ##3. Dioda LED

# %%
U = list(range(1, 13))
I = [0.003, 0.504, 1.405, 2.355, 3.322, 4.297, 5.277, 6.261, 7.247, 8.234, 9.223, 10.214]

Rdyn = [round(U[0] / (I[0] / 1000),3)]

for k in range(1, len(U)):
    delta_U = U[k] - U[k - 1]
    delta_I = I[k] - I[k - 1]
    if delta_I == 0:
        R = float('inf')
    else:
        R = delta_U / (delta_I / 1000)
    Rdyn.append(round(R,3))

wyniki = pd.DataFrame({
    "U [V]": U,
    "I [mA]": I,
    "Rdyn [Ω]": Rdyn
})

fig, ax = plt.subplots(figsize=(12, 2.5))
ax.axis('off')
table_data = [
    ["U [V]"] + U,
    ["I [mA]"] + [f"{x:.3f}" for x in I],
    ["Rdyn [Ω]"] + ["N/A" if x is None else str(x) for x in Rdyn]
]
table = ax.table(cellText=table_data, loc='center', cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)
plt.title("Tabela nr 3A: Pomiary diody LED w kierunku przewodzenia")



plt.figure(figsize=(8, 5))
plt.plot(U[0:], Rdyn[0:], marker='o', color='green')
plt.title("Rezystancja dynamiczna dla diody LED w kierunku przewodzenia")
plt.xlabel("U [V]")
plt.ylabel("Rdyn [Ω]")
plt.grid(True)
plt.tight_layout()

# %%
U = list(range(0, 13))
I = [-93.197]*13 #w pA
I[0] = 0

Rdyn = [0]

for k in range(1, len(U)):
    delta_U = U[k] - U[k - 1]
    delta_I = I[k] - I[k - 1]
    if delta_I == 0:
        R = float('inf')
    else:
        R = delta_U / (delta_I / 1000)
    Rdyn.append(round(R,3))

wyniki = pd.DataFrame({
    "U [V]": U,
    "I [mA]": I,
    "Rdyn [Ω]": Rdyn
})

fig, ax = plt.subplots(figsize=(12, 2.5))
ax.axis('off')
table_data = [
    ["U [V]"] + U,
    ["I [pA]"] + [f"{x:.3f}" for x in I],
    ["Rdyn [Ω]"] + ["N/A" if x is None else str(x) for x in Rdyn]
]
table = ax.table(cellText=table_data, loc='center', cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)
plt.title("Tabela nr 3A: Pomiary diody LED w kierunku zaporowym")



plt.figure(figsize=(8, 5))
plt.plot(U[0:], Rdyn[0:], marker='o', color='green')
plt.title("Rezystancja dynamiczna dla diody LED w kierunku zaporowym")
plt.xlabel("U [V]")
plt.ylabel("Rdyn [Ω]")
plt.grid(True)
plt.tight_layout()
plt.xlim(0, max(U) if U else 1)
plt.ylim(0, max(Rdyn) if Rdyn else 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-19b33f2b74f0> in <cell line: 0>()
#      43 plt.tight_layout()
#      44 plt.xlim(0, max(U) if U else 1)
# ---> 45 plt.ylim(0, max(Rdyn) if Rdyn else 1)
#      46
#      47
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in ylim(*args, **kwargs)
#    2158     if not args and not kwargs:
#    2159         return ax.get_ylim()
# -> 2160     ret = ax.set_ylim(*args, **kwargs)
#    2161     return ret
#    2162
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    4015                 raise TypeError("Cannot pass both 'top' and 'ymax'")
#    4016             top = ymax
# -> 4017         return self.yaxis._set_lim(bottom, top, emit=emit, auto=auto)
#    4018
# ...
